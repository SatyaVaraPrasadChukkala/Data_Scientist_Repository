# %% [markdown]
# # The Battle of Neighbourhood - ABC Co.,

# %% [markdown]
# ## Introduction:

# %% [markdown]
# ABC Co., is looking forward to Start a Business by Opening a New Restuarent in New York City and requested Me as a Data
# Scientist to Study the current and Historical New York data to comeup with a best possible place in New york.
#
# ## Business Problem :
#
# Identifying the below criteria to make the Business success, feasibility for growth and spreading the brand across the citities.
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# 1. [Location / Area](#0)<br>
# 2. [Top Cusines to Start with](#2)<br>
# 3. [Farmer Markets accessability](#3)<br>
# 4. [Saturated & Un Saturated Markets](#4)<br>
# 5. [Untapped Markets](#5)<br>
# 6. [Other Criteria - as per ABC Co.,](#6)<br>
#
# </div>
# <hr>
#
# ### Success Criteria :
#
# Best neighborhood which meets above criteria.

# %% [markdown]
# ## Data Requirement :
#
# Data required for the purpose of Analysis to meet the Business requirement is :
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# 1. [New York Demographic Details for the Borough and County level details.](#0)<br>
# 2. [Population and Top Cusines in New York](#2)<br>
# 3. [Farmer Markets details and Locations](#3)<br>
# 4. [Neighbourhood details with Locations](#4)<br>
# 5. [Other Criteria - as per ABC Co.,](#6)<br>
#
# </div>
# <hr>
#
# Need to check through different portals for the availability of required Data.

# %% [markdown]
# ## Data Collection & Data Cleansing :
#
# Data Collected fromt different Web portals for the Analysis as below.

# %% [markdown]
# ### Data Set 1. Boroughs of NewYork City -  Data Collected from
#
#    Web Portal : https://en.wikipedia.org/wiki/Boroughs_of_New_York_City.
#
#    Borough Details in NewYork and the corresponding details of Population, GDP, Area & Density.
#
#    ![image.png](attachment:image.png)
#
# ##### *Data is Clean and no Cleaning required.

# %% [markdown]
# ### Data Set 2. Farmer Markets Details -  Data Collected from
#
#    Web Portal : https://en.wikipedia.org/wiki/Boroughs_of_New_York_City.
#
#    Farmer Markets are the areas where the nearby formers sell their products.  Markets are easily accessible for the Vegeatables, Non-Vegetarian items like Fish, meet, labsters etc., and also the spices. which are the key ingrediants afor the Restaurent.
#
# This will impact the restaurent depending on the distance.  If the Farmer market is situated long from the restaurent then the transaportation cost will increase and same time the perishable items may get spoil.
#
# So the lesser distance be much better to serve the dishes fresh and tasty.
#
#    ![image.png](attachment:image.png)
#
# ##### *Data is Clean and no Cleaning required.  * And we have checked for the spread of Market places and Analyzing at ingrediant levels is not scope.

# %% [markdown]
# ### Data Set 3. Cusine Details -  Data Collected from
#
#    Web Portal : https://en.wikipedia.org/wiki/Cuisine_of_New_York_City.
#
#    Cusine details required to Analyze the Top Cusines in NewYork to understand the people tasts and the best selling in each Borough of New York.
#
# This will be one of the key decision making Data,  as it gives the people taste and we can anlyze the saturated markets for this Cusine.
#
# So the top Cusines were considered for the New Restaurent.  Below is the Screenshot from Cleaned Table
#
# ![image.png](attachment:image.png)
#
# ##### *Data is Cleaned and stored in a CSV file for use.  * And we have checked for the top Cusines in New York.

# %% [markdown]
# ### Data Set 4. FourSquare Data for the Neibhourhood  -  Data Collected FourSquare
#
#    Web Portal : https://api.foursquare.com/v2/venues/explore.
#
#    Usine details required to Analyze the Neighbourhood venues and Clustering the Neibourhoods for the Analytical Analysis.
#
#    Analyzing the data for the Silhouette Coefficient and K Means to Analyze the Saturated Markets and Competitive markets.
#
# ![image.png](attachment:image.png)
#
# ##### *Data is Cleaned and stored in a CSV file for use.

# %% [markdown]
# ## Data Methodology / Analysis :

# %% [markdown]
# ### Analysis 1 :  Analyzing the Top Cusines in New York
#
# For the Analysis used the DataSet 3 (Data Collected from wikipedia) to know the top Cusines in NewYork.
#
# Top Cusines in New York are as below
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Top 5 Cusines in Each Borough are as below.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Analysis 2 :  Farmer Markets
#
# For the Analysis used the DataSet 2 (Data Collected from wikipedia) to know the spread of Markets.
#
# with Location Map we have come to a decision that the Markets are spread across NewYork Evenly and easily accessible.
#
# Observed :  Spread is more in case of Brooklyn & Manhattan
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Analysis 3 :  Neibhourhood Analysis - FourSquare Data
#
# 1) NewYork city geographical coordinates data has be utilized as input for the Foursquare API, that has been leveraged to
# provision venues information for each neighborhood.
#
# 2) We used the Foursquare API data to explore neighborhoods in New York City.
#
# 3) Using the geographical coordinates of each neighbourhood foursquare API calls are made to get top 200 venues in a radius of 1000 meters
#
#  PART – 1 Brooklyn and Manhattan
#  PART – 2 Bronx, Queens and Staten Island

# %% [markdown]
# ### PART 1 :
#
# #### Segmenting and Clustering Neighborhoods -  Brooklyn and Manhattan
#
# The geographical coordinates of "New York City, NY" are 40.7127281, -74.0060152.
#
# The "New York City, NY" dataframe has 406 different venue types and 110 neighborhoods.
#
# #### Cluster results are as below
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ####KMeans of Cluster as below :
#
# ![image.png](attachment:image.png)
#
# Neighbourhood Plot looks as below

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### PART 2 :
#
# #### Segmenting and Clustering Neighborhoods -  Bronx, Queens and Staten Island
#
# The geographical coordinates of "New York City, NY" are 40.7127281, -74.0060152.
#
# The "New York City, NY" dataframe has 385 different venue types and 194 neighborhoods.
#
# #### Cluster Results are as below
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ####KMeans of Cluster as below :
#
# ![image.png](attachment:image.png)
#
# Neighbourhood Plot looks as below

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Discussion :
#
# 1) Scope to explore cuisines of various countries in Bronx, Queens and Staten Island
#
# 2) In Manhattan and Brooklyn restaurants , cuisines of many countries are part of their Menu. Risk can be taken with great menu
# on board. It also shows people love and explore cuisines of various countries.
#
# 3) Scope to increase Farmers markets in Bronx, Queens and Staten Island. - Region - Cluster0 - Neighborhood – Staten Island –
# Tod Hill, Port Ivory, Bloomfield

# %% [markdown]
# ## Conclusion :
#
# Basing on the Analysis of the Data it is advisable to place the restuarent in the
#
# 1) Non-saturated place -  As per Analysis Staten Iland and Bronx
#
# 2) Cusine - Top 5 Cusines (Italian, Purot recon, Mexican, Jewish, India)
#
# 3) Farmer markets are evenly spread and will not impact the place much.
#
# I conclude to ABC Co., to Place the restaurent in the place meets these criteria.
